# %%
import math
import pandas as pd
# import altair as alt
import numpy as np
# import matplotlib.pyplot as plt
from scipy import stats
# import statsmodels.api as sm
# import statsmodels.formula.api as smf
# import seaborn as sns
# from statsmodels.tools import eval_measures
# alt.renderers.enable('notebook')

from geopy import geocoders  
gn = geocoders.GeoNames(username='doomibox')

# %%
nflis_data = pd.read_csv("2018_MCMProblemC_DATA/updated_nflis_data.csv")
nflis_data = nflis_data.assign(location = lambda x: x.County + ", " + x.State)

# %%
nflis_data.head()
# Out:
#    Year State        County SubstanceName  DrugReports  DrugReportsCounty  \
# 0  2010    VA  PITTSYLVANIA     Methadone            2                 16
# 1  2010    VA  PITTSYLVANIA        Heroin            1                 16
# 2  2010    VA  PITTSYLVANIA   Hydrocodone            7                 16
# 3  2010    VA  PITTSYLVANIA     Oxycodone            5                 16
# 4  2010    VA  PITTSYLVANIA      Morphine            1                 16
#
#    TotalDrugReportsCounty  DrugReportsState  TotalDrugReportsState  \
# 0                     182              8685                  41462
# 1                     182              8685                  41462
# 2                     182              8685                  41462
# 3                     182              8685                  41462
# 4                     182              8685                  41462
#
#    County_Rate  State_Rate  County_Rate_Total  State_Rate_Total
# 0       0.1250    0.000230           0.010989          0.000048
# 1       0.0625    0.000115           0.005495          0.000024
# 2       0.4375    0.000806           0.038462          0.000169
# 3       0.3125    0.000576           0.027473          0.000121
# 4       0.0625    0.000115           0.005495          0.000024

# %%
substance_lst =set(nflis_data['SubstanceName'])

# %%
print(substance_lst)
# Out:
# {'3-Methylfentanyl', 'Phenyl fentanyl', 'Thebaine', 'Benzylfentanyl', 'Butorphanol', 'Methorphan', 'Butyryl fentanyl', 'Nalbuphine', 'Furanyl/3-Furanyl fentanyl', 'Buprenorphine', 'Valeryl fentanyl', 'MT-45', 'Heroin', 'Hydromorphone', 'Cyclopentyl fentanyl', 'Cyclopropyl/Crotonyl Fentanyl', '4-Fluoroisobutyryl fentanyl', 'Dihydrocodeine', 'Remifentanil', 'Oxymorphone', 'Hydrocodeinone', 'U-47700', 'Fluorofentanyl', 'Acetyl fentanyl', 'cis-3-methylfentanyl', 'Propoxyphene', 'Pentazocine', 'Dextropropoxyphene', 'Alphaprodine', 'Furanyl fentanyl', 'Opium', 'Hydrocodone', 'o-Fluorofentanyl', '3-Fluorofentanyl', 'trans-3-Methylfentanyl', 'p-Fluorofentanyl', 'Cyclopropyl fentanyl', 'U-48800', 'U-49900', 'Fentanyl', 'Codeine', 'Dihydromorphone', 'Metazocine', 'Desmethylprodine ', 'Acetyldihydrocodeine', 'ANPP', 'Methoxyacetyl fentanyl', 'Isobutyryl fentanyl', 'U-51754', 'Acetylcodeine', '4-Methylfentanyl', 'p-methoxybutyryl fentanyl', 'Mitragynine', 'Tramadol', 'Crotonyl fentanyl', 'Opiates', 'Fluoroisobutyryl fentanyl', 'Meperidine', 'Pethidine', 'Morphine', 'Carfentanil', 'Fluorobutyryl fentanyl ', 'Tetrahydrofuran fentanyl', 'Oxycodone', 'Methadone', 'Levorphanol', '3,4-Methylenedioxy U-47700', 'Acryl fentanyl', 'p-Fluorobutyryl fentanyl'}

# %%
def count_num_distri(substanceName):
    data = nflis_data.loc[nflis_data['SubstanceName'] == substanceName]
    data_dict = {}
    for state in list(data['State']):
        data_dict[state] = sum(data.loc[data['State'] == state]['DrugReports'])
    return data_dict

# %%
distri_dict = {}
for substance in substance_lst:
    distri_dict[substance] = (count_num_distri(substance))
distri_dict
# Out:
# {'3-Methylfentanyl': {'VA': 10, 'WV': 5, 'OH': 941, 'PA': 256},
#  'Phenyl fentanyl': {'WV': 1, 'OH': 54, 'PA': 9},
#  'Thebaine': {'WV': 1, 'KY': 1, 'PA': 2, 'OH': 7},
#  'Benzylfentanyl': {'VA': 1, 'OH': 115, 'PA': 36},
#  'Butorphanol': {'VA': 6, 'PA': 1, 'OH': 1},
#  'Methorphan': {'VA': 48, 'WV': 28, 'OH': 30, 'KY': 124, 'PA': 79},
#  'Butyryl fentanyl': {'PA': 132, 'VA': 6, 'OH': 221, 'WV': 3, 'KY': 17},
#  'Nalbuphine': {'VA': 1},
#  'Furanyl/3-Furanyl fentanyl': {'WV': 7},
#  'Buprenorphine': {'VA': 7147,
#   'WV': 1223,
#   'OH': 10687,
#   'KY': 6428,
#   'PA': 9354},
#  'Valeryl fentanyl': {'OH': 2, 'PA': 19},
#  'MT-45': {'PA': 2},
#  'Heroin': {'VA': 24441, 'WV': 9453, 'OH': 133137, 'KY': 23377, 'PA': 119907},
#  'Hydromorphone': {'VA': 2472, 'WV': 955, 'OH': 804, 'KY': 535, 'PA': 357},
#  'Cyclopentyl fentanyl': {'KY': 1},
#  'Cyclopropyl/Crotonyl Fentanyl': {'OH': 26},
#  '4-Fluoroisobutyryl fentanyl': {'VA': 253,
#   'OH': 112,
#   'PA': 328,
#   'WV': 2,
#   'KY': 3},
#  'Dihydrocodeine': {'WV': 1, 'PA': 2, 'KY': 1, 'VA': 5, 'OH': 4},
#  'Remifentanil': {'PA': 1},
#  'Oxymorphone': {'VA': 1070, 'WV': 731, 'OH': 1526, 'KY': 1278, 'PA': 758},
#  'Hydrocodeinone': {'PA': 3},
#  'U-47700': {'VA': 90, 'WV': 11, 'OH': 1096, 'KY': 80, 'PA': 315},
#  'Fluorofentanyl': {'OH': 2, 'KY': 1},
#  'Acetyl fentanyl': {'VA': 50, 'OH': 1361, 'PA': 545, 'WV': 59, 'KY': 36},
#  'cis-3-methylfentanyl': {'PA': 23, 'KY': 2},
#  'Propoxyphene': {'VA': 117, 'OH': 223, 'KY': 61, 'PA': 167, 'WV': 3},
#  'Pentazocine': {'VA': 13, 'WV': 7, 'KY': 16, 'OH': 15, 'PA': 4},
#  'Dextropropoxyphene': {'WV': 36, 'OH': 36, 'PA': 6},
#  'Alphaprodine': {'PA': 1},
#  'Furanyl fentanyl': {'OH': 1738, 'PA': 721, 'VA': 570, 'WV': 42, 'KY': 148},
#  'Opium': {'VA': 28, 'PA': 1, 'OH': 1, 'KY': 1},
#  'Hydrocodone': {'VA': 10327,
#   'WV': 2460,
#   'OH': 13943,
#   'KY': 14540,
#   'PA': 6100},
#  'o-Fluorofentanyl': {'VA': 3, 'OH': 4},
#  '3-Fluorofentanyl': {'VA': 1},
#  'trans-3-Methylfentanyl': {'PA': 21, 'KY': 2},
#  'p-Fluorofentanyl': {'WV': 1, 'OH': 6},
#  'Cyclopropyl fentanyl': {'KY': 79, 'VA': 27, 'WV': 3, 'OH': 730, 'PA': 102},
#  'U-48800': {'OH': 23, 'PA': 12},
#  'U-49900': {'OH': 17},
#  'Fentanyl': {'VA': 2797, 'WV': 618, 'OH': 26453, 'KY': 4280, 'PA': 13191},
#  'Codeine': {'VA': 631, 'WV': 53, 'OH': 1312, 'KY': 320, 'PA': 1834},
#  'Dihydromorphone': {'PA': 1},
#  'Metazocine': {'PA': 1},
#  'Desmethylprodine ': {'VA': 2, 'OH': 8, 'KY': 5},
#  'Acetyldihydrocodeine': {'PA': 5},
#  'ANPP': {'PA': 21, 'OH': 278, 'KY': 19, 'VA': 4, 'WV': 1},
#  'Methoxyacetyl fentanyl': {'VA': 9, 'WV': 2, 'OH': 218, 'KY': 17, 'PA': 79},
#  'Isobutyryl fentanyl': {'WV': 3, 'OH': 1},
#  'U-51754': {'OH': 7},
#  'Acetylcodeine': {'WV': 5, 'PA': 7, 'VA': 1},
#  '4-Methylfentanyl': {'OH': 5},
#  'p-methoxybutyryl fentanyl': {'PA': 1},
#  'Mitragynine': {'KY': 58, 'OH': 125, 'PA': 6, 'VA': 4, 'WV': 3},
#  'Tramadol': {'VA': 1339, 'OH': 2796, 'KY': 789, 'PA': 1408, 'WV': 67},
#  'Crotonyl fentanyl': {'OH': 39},
#  'Opiates': {'OH': 57, 'PA': 3},
#  'Fluoroisobutyryl fentanyl': {'OH': 103, 'VA': 12, 'KY': 4, 'PA': 36},
#  'Meperidine': {'VA': 49, 'OH': 20, 'KY': 13, 'PA': 15, 'WV': 7},
#  'Pethidine': {'KY': 6, 'PA': 6, 'VA': 1, 'OH': 1},
#  'Morphine': {'VA': 2908, 'WV': 615, 'OH': 3180, 'KY': 1852, 'PA': 2027},
#  'Carfentanil': {'VA': 58, 'WV': 8, 'OH': 5415, 'KY': 169, 'PA': 178},
#  'Fluorobutyryl fentanyl ': {'WV': 1, 'OH': 22},
#  'Tetrahydrofuran fentanyl': {'OH': 5, 'PA': 1},
#  'Oxycodone': {'VA': 16735, 'WV': 7037, 'OH': 35988, 'KY': 25586, 'PA': 24827},
#  'Methadone': {'VA': 2182, 'WV': 131, 'OH': 2464, 'KY': 2143, 'PA': 1793},
#  'Levorphanol': {'PA': 2},
#  '3,4-Methylenedioxy U-47700': {'PA': 3},
#  'Acryl fentanyl': {'VA': 10, 'WV': 13, 'OH': 1227, 'KY': 52, 'PA': 63},
#  'p-Fluorobutyryl fentanyl': {'OH': 3, 'KY': 1, 'PA': 10, 'VA': 2}}

# %%
nflis_data.loc[ (nflis_data['SubstanceName'] == 'Heroin') & (nflis_data['location'] == 'AUGUSTA, VA')].sort_values(by='Year')
# Out:
#        Year State   County SubstanceName  DrugReports  DrugReportsCounty  \
# 2881   2011    VA  AUGUSTA        Heroin            3                 41
# 5589   2012    VA  AUGUSTA        Heroin            1                 33
# 8377   2013    VA  AUGUSTA        Heroin            4                 17
# 11214  2014    VA  AUGUSTA        Heroin           15                 87
# 14073  2015    VA  AUGUSTA        Heroin           24                 59
# 16945  2016    VA  AUGUSTA        Heroin           15                 88
# 20268  2017    VA  AUGUSTA        Heroin           12                 59
#
#        TotalDrugReportsCounty  DrugReportsState  TotalDrugReportsState  \
# 2881                      324              6749                  28969
# 5589                      308              7831                  32251
# 8377                      246             11675                  47694
# 11214                     425              9037                  32265
# 14073                     238              8810                  27819
# 16945                     469             10195                  33539
# 20268                     471             10448                  36994
#
#        County_Rate  State_Rate  County_Rate_Total  State_Rate_Total  \
# 2881      0.073171    0.000445           0.009259          0.000104
# 5589      0.030303    0.000128           0.003247          0.000031
# 8377      0.235294    0.000343           0.016260          0.000084
# 11214     0.172414    0.001660           0.035294          0.000465
# 14073     0.406780    0.002724           0.100840          0.000863
# 16945     0.170455    0.001471           0.031983          0.000447
# 20268     0.203390    0.001149           0.025478          0.000324
#
#           location
# 2881   AUGUSTA, VA
# 5589   AUGUSTA, VA
# 8377   AUGUSTA, VA
# 11214  AUGUSTA, VA
# 14073  AUGUSTA, VA
# 16945  AUGUSTA, VA
# 20268  AUGUSTA, VA

# %%
nflis_data.loc[ (nflis_data['SubstanceName'] == 'Heroin') & (nflis_data['location'] == 'NELSON, VA')].sort_values(by='Year')
# Out:
#        Year State  County SubstanceName  DrugReports  DrugReportsCounty  \
# 11594  2014    VA  NELSON        Heroin            2                  2
# 14427  2015    VA  NELSON        Heroin            2                  8
# 17373  2016    VA  NELSON        Heroin            4                 20
# 20757  2017    VA  NELSON        Heroin           44                 91
#
#        TotalDrugReportsCounty  DrugReportsState  TotalDrugReportsState  \
# 11594                      91              9037                  32265
# 14427                      38              8810                  27819
# 17373                     161             10195                  33539
# 20757                     467             10448                  36994
#
#        County_Rate  State_Rate  County_Rate_Total  State_Rate_Total  \
# 11594     1.000000    0.000221           0.021978          0.000062
# 14427     0.250000    0.000227           0.052632          0.000072
# 17373     0.200000    0.000392           0.024845          0.000119
# 20757     0.483516    0.004211           0.094218          0.001189
#
#          location
# 11594  NELSON, VA
# 14427  NELSON, VA
# 17373  NELSON, VA
# 20757  NELSON, VA

# %%
gn.geocode("AUGUSTA, VA")
# Out:
# Location(Augusta, Virginia, United States, (38.16452, -79.13383, 0.0))
